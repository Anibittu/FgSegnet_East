# %% [markdown]
# Data extraction from website by beautiful soup

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as BS
import pandas as pd
from urllib.parse import urlparse, urlsplit
from PIL import Image

website_page = 'https://en.wikipedia.org/wiki/Chernobyl_disaster'
page = urlopen(website_page)
soup = BS(page)
soup

title_links = soup.find_all('h3', class_='entry-title')
title_links

links = {}
for i in range(0, len(title_links)):
    _title = title_links[i]
    only_title = _title.text.strip()
    print(_title.text.strip())
    _link = [n['href'] for n in _title]
    only_link = _link[0]
    webpage_2 = only_link
    print(webpage_2)
    open_webpage_2 = urlopen(webpage_2)
    soup2 = BS(open_webpage_2)
    ex = soup2.find_all(['p', 'h4'])
    post_Text = ''
    for j in ex:
        post_Text += j.text.strip() 
    
    print(_link[0])
    links[i]=[only_title, only_link, post_Text]
links
A = []
B = []
C = []
for i in range(0, len(links)):
    A.append(links[i][0])
    B.append(links[i][1])
    C.append(links[i][2])

df = pd.DataFrame(A, columns=['Title'])
df['Link']=B
df['Post']=C

df.to_csv('file_name.csv', sep='\t', encoding='utf-8')

# %% [markdown]
# Left flip and right filp of the data

# %%
import imageio
import imgaug as ia
import imgaug.augmenters as iaa
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib
import cv2
import glob
import os
# %matplotlib inline
#path ='/home/anish/denoising-dirty-documents/denoising-dirty-documents/train_cleaned'
path ='/home/anish/denoising-dirty-documents/denoising-dirty-documents/train'
X_list = glob.glob(os.path.join(path,'*.png' ))
print(len(X_list))
t=1
for i in range(len(X_list)):
    image = imageio.imread(X_list[i])
    rotate=iaa.Affine(rotate=(-50, 30))
    rotated_image=rotate.augment_image(image)
    #cv2.imwrite('/home/anish/denoising-dirty-documents/denoising-dirty-documents/rotated_gt/{}.jpg'.format(t),rotated_image)
    cv2.imwrite('/home/anish/denoising-dirty-documents/denoising-dirty-documents/rotated_ti/{}.jpg'.format(t),rotated_image)
    t=t+1
# Out:
# 144

# %%
import imageio
import imgaug as ia
import imgaug.augmenters as iaa
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib
import cv2
import glob
import os
# %matplotlib inline
#path ='/home/anish/denoising-dirty-documents/denoising-dirty-documents/train_cleaned'
path ='/home/anish/denoising-dirty-documents/denoising-dirty-documents/train'
X_list = glob.glob(os.path.join(path,'*.png' ))
print(len(X_list))
t=1
for i in range(len(X_list)):
    image = imageio.imread(X_list[i])
    flip_hr=iaa.Fliplr(p=1.0)
    flip_hr_image= flip_hr.augment_image(image)
    #cv2.imwrite('/home/anish/denoising-dirty-documents/denoising-dirty-documents/fliphorizontal_gt/fh{}.jpg'.format(t),flip_hr_image)
    cv2.imwrite('/home/anish/denoising-dirty-documents/denoising-dirty-documents/fliphorizontal_ti/fh{}.jpg'.format(t),flip_hr_image)
    t=t+1
# Out:
# 144

# %%
import imageio
import imgaug as ia
import imgaug.augmenters as iaa
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib
import cv2
import glob
import os
# %matplotlib inline
#path1 ='/home/anish/denoising-dirty-documents/denoising-dirty-documents/train_cleaned'
path ='/home/anish/denoising-dirty-documents/denoising-dirty-documents/train'
X_list = glob.glob(os.path.join(path1,'*.png' ))
print(len(X_list))
t=1
for i in range(len(X_list)):
    image = imageio.imread(X_list[i])
    flip_vr=iaa.Flipud(p=1.0)
    flip_vr_image= flip_vr.augment_image(image)
    #cv2.imwrite('/home/anish/denoising-dirty-documents/denoising-dirty-documents/flipvertical_gt/fv{}.jpg'.format(t),flip_hr_image)
    cv2.imwrite('/home/anish/denoising-dirty-documents/denoising-dirty-documents/flipvertical_ti/fv{}.jpg'.format(t),flip_hr_image)
    t=t+1
# Out:
# 144

# %%
import imageio
import imgaug as ia
import imgaug.augmenters as iaa
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib
import cv2
import glob
import os
# %matplotlib inline
#path1 ='/home/anish/denoising-dirty-documents/denoising-dirty-documents/train_cleaned'
path ='/home/anish/denoising-dirty-documents/denoising-dirty-documents/train'
X_list = glob.glob(os.path.join(path1,'*.png' ))
print(len(X_list))
t=1
for i in range(len(X_list)):
    image = imageio.imread(X_list[i])
    scale_im=iaa.Affine(scale={"x": (1.5, 1.0), "y": (1.5, 1.0)})
    scale_image =scale_im.augment_image(image)
    #cv2.imwrite('/home/anish/denoising-dirty-documents/denoising-dirty-documents/scale_up_gt/scu{}.jpg'.format(t),   scale_image)
    cv2.imwrite('/home/anish/denoising-dirty-documents/denoising-dirty-documents/scale_up_ti/scu{}.jpg'.format(t),  scale_image)
    t=t+1
# Out:
# 144

# %%
image = imageio.imread("C:\\Data\\img Aug\\car2.jpeg")
scale_im=iaa.Affine(scale={"x": (1.5, 1.0), "y": (1.5, 1.0)})
scale_image =scale_im.augment_image(image)
ia.imshow(scale_image)

# %%
from pdf2image.exceptions import (
    PDFInfoNotInstalledError,
    PDFPageCountError,
    PDFSyntaxError
)

# %%
from pdf2image import convert_from_path, convert_from_bytes

# %%
images = convert_from_path('v214.pdf')

# %%
print(images)
# Out:
# [<PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1653x2339 at 0x7F5FC01806D0>, <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1653x2339 at 0x7F5FC2A70D10>]

# %%
i=1
for page in images:
    page.save('out{}.jpg'.format(i), 'JPEG')
    i=i+1;

# %%
import cv2
img = cv2.imread('out1.jpg')
resized_image = cv2.resize(img, (540, 420))

# %%
cv2.imwrite("hehe.jpg",resized_image)
# Out:
# True

# %%
import imageio
import imgaug as ia
import imgaug.augmenters as iaa
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib
import cv2
import glob
import os
import cv2

# %%
import cv2
img = cv2.imread('out1.jpg')
crop = iaa.Crop(percent=(0.3, 0.3)) # crop image
corp_image=crop.augment_image(img)
resize= cv2.resize(corp_image,(540,420))
ia.imshow(corp_image)

# %%
ia.imshow(resize)

# %%
cv2.imwrite("resize.jpg",resize)
# Out:
# True

# %%
from pdf2image import convert_from_path, convert_from_bytes
from pdf2image.exceptions import (
    PDFInfoNotInstalledError,
    PDFPageCountError,
    PDFSyntaxError
)

# %%
path ='/home/anish/ubantu/table/sabha'
t=1
X_list = glob.glob(os.path.join(path,'*.pdf' ))
print(len(X_list))
# Out:
# 35

# %%
for i in range(len(X_list)):
    images = convert_from_path(X_list[i])
    for page in images:
        page.save('out{}.jpg'.format(t), 'JPEG')
        t=t+1;

# %%
t
# Out:
# 135

# %%
path ='/home/anish/denoising-dirty-documents/pdfs'
X_list= glob.glob(os.path.join(path,'*.jpg'))
print(len(X_list))
# Out:
# 134

# %%
p=1
for i in range(len(X_list)):
    img = cv2.imread(X_list[i])
    crop = iaa.Crop(percent=(0.3, 0.3)) # crop image
    corp_image=crop.augment_image(img)
    resize= cv2.resize(corp_image,(540,420))
    cv2.imwrite('/home/anish/denoising-dirty-documents/denoising-dirty-documents/pdf{}.jpg'.format(p),resize)
    p=p+1

# %%
image=cv2.imread('resize.jpg')
gaussian_noise=iaa.AdditiveGaussianNoise(10,20)
noise_image=gaussian_noise.augment_image(image)
ia.imshow(noise_image)

# %%
from skimage.util import random_noise
noise_img = random_noise(image, mode='s&p',amount=0.3)
 
# The above function returns a floating-point image
# on the range [0, 1], thus we changed it to 'uint8'
# and from [0,255]
noise_img = np.array(255*noise_img, dtype = 'uint8')
 
# Display the noise image
cv2.imshow('blur',noise_img)
cv2.waitKey(0)

# %%
cv2.destroyAllWindows()

# %%
path='home/anish/denoising-dirty-documents/denoising-dirty-documents/pdf_gt'
X_list = glob.glob(os.path.join(path,'*.png'))

# %% [markdown]
# Now on i will add noise batchwise in pdf and once it get done i will agument it to expand the data

# %%
path='/home/anish/denoising-dirty-documents/denoising-dirty-documents/pdf_gt'
X_list = glob.glob(os.path.join(path,'*.jpg'))
t=1
for i in range(len(X_list)):
    if(i<27):
        image=cv2.imread(X_list[i])
        gaussian_noise=iaa.AdditiveGaussianNoise(1,20)
        noise_image=gaussian_noise.augment_image(image)
        cv2.imwrite('/home/anish/denoising-dirty-documents/denoising-dirty-documents/pdf_gt/pdf{}.jpg'.format(t),noise_image)
    elif(i>=27 and i<54):
        image=cv2.imread(X_list[i])
        gaussian_noise=iaa.AdditiveGaussianNoise(1,30)
        noise_image=gaussian_noise.augment_image(image)
        cv2.imwrite('/home/anish/denoising-dirty-documents/denoising-dirty-documents/pdf_gt/pdf{}.jpg'.format(t),noise_image)
    elif(i>=54 and i<81):
        image=cv2.imread(X_list[i])
        gaussian_noise=iaa.AdditiveGaussianNoise(1,40)
        noise_image=gaussian_noise.augment_image(image)
        cv2.imwrite('/home/anish/denoising-dirty-documents/denoising-dirty-documents/pdf_gt/pdf{}.jpg'.format(t),noise_image)
    elif(i>=81 and i<108):
        image=cv2.imread(X_list[i])
        gaussian_noise=iaa.AdditiveGaussianNoise(1,50)
        noise_image=gaussian_noise.augment_image(image)
        cv2.imwrite('/home/anish/denoising-dirty-documents/denoising-dirty-documents/pdf_gt/pdf{}.jpg'.format(t),noise_image)
    else:
        image=cv2.imread(X_list[i])
        gaussian_noise=iaa.AdditiveGaussianNoise(10,20)
        noise_image=gaussian_noise.augment_image(image)
        cv2.imwrite('/home/anish/denoising-dirty-documents/denoising-dirty-documents/pdf_gt/pdf{}.jpg'.format(t),noise_image)
    t=t+1

# %%
t
# Out:
# 135

# %%
len(X_list)
# Out:
# 134

# %%
path='/home/anish/denoising-dirty-documents/denoising-dirty-documents/pdf_gt'
X_list = glob.glob(os.path.join(path,'*.jpg'))

# %%
path ='/home/anish/denoising-dirty-documents/denoising-dirty-documents/train'
X_list = glob.glob(os.path.join(path,'*.png' ))

# %%
import imageio
import imgaug as ia
import imgaug.augmenters as iaa
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib
import cv2
import glob
import os
# %matplotlib inline
path ='/home/anish/denoising-dirty-documents/denoising-dirty-documents/pdf_gt'
#path ='/home/anish/denoising-dirty-documents/denoising-dirty-documents/pdf_ti'
X_list = glob.glob(os.path.join(path,'*.jpg' ))
print(len(X_list))
t=1
for i in range(len(X_list)):
    image = imageio.imread(X_list[i])
    flip_hr=iaa.Fliplr(p=1.0)
    flip_hr_image= flip_hr.augment_image(image)
    #cv2.imwrite('/home/anish/denoising-dirty-documents/denoising-dirty-documents/fliph_pdf_ti/fhpdf{}.jpg'.format(t),flip_hr_image)
    cv2.imwrite('/home/anish/denoising-dirty-documents/denoising-dirty-documents/fliph_pdf_gt/fhpdf{}.jpg'.format(t),flip_hr_image)
    t=t+1
# Out:
# 134

# %%
import imageio
import imgaug as ia
import imgaug.augmenters as iaa
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib
import cv2
import glob
import os
# %matplotlib inline
#path ='/home/anish/denoising-dirty-documents/denoising-dirty-documents/pdf_gt'
path ='/home/anish/denoising-dirty-documents/denoising-dirty-documents/pdf_ti'
X_list = glob.glob(os.path.join(path,'*.jpg' ))
print(len(X_list))
t=1
for i in range(len(X_list)):
    image = imageio.imread(X_list[i])
    flip_hr=iaa.Fliplr(p=1.0)
    flip_hr_image= flip_hr.augment_image(image)
    cv2.imwrite('/home/anish/denoising-dirty-documents/denoising-dirty-documents/flipv_pdf_ti/fvpdf{}.jpg'.format(t),flip_hr_image)
    #cv2.imwrite('/home/anish/denoising-dirty-documents/denoising-dirty-documents/flipv_pdf_gt/fvpdf{}.jpg'.format(t),flip_hr_image)
    t=t+1
# Out:
# 134

# %%
image = imageio.imread("resize.jpg")
scale_im=iaa.Affine(scale={"x": (.9, 1.0), "y": (.9, 1.0)})
scale_image =scale_im.augment_image(image)
ia.imshow(scale_image)

# %%
img=cv2.imread("resize.jpg")
ia.imshow(img)

# %%
path ='/home/anish/denoising-dirty-documents/denoising-dirty-documents/train_cleaned'
X_list = glob.glob(os.path.join(path,'*.png'))

# %%
print(len(X_list))
# Out:
# 144

# %%
t=1
for i in range(len(X_list)):
    image = imageio.imread(X_list[i])
    flip_vr=iaa.Flipud(p=1.0)
    flip_vr_image= flip_vr.augment_image(image)
    #cv2.imwrite('/home/anish/denoising-dirty-documents/denoising-dirty-documents/scale_up_gt/scu{}.jpg'.format(t),   scale_image)
    cv2.imwrite('/home/anish/denoising-dirty-documents/denoising-dirty-documents/flipvertical_ti/fv{}.jpg'.format(t),flip_vr_image)
    t=t+1

# %%
t=1
for i in range(len(X_list)):
    image = cv2.imread(X_list[i])
    cv2.imwrite('/home/anish/denoising-dirty-documents/denoising-dirty-documents/ori_gt/ori{}.jpg'.format(t), image)
    t=t+1

# %%
import pytesseract

# %%
 ocd =pytesseract.image_to_osd ('resize.jpg')

# %%
print(ocd)
# Out:
# Page number: 0
# Orientation in degrees: 0
# Rotate: 0
# Orientation confidence: 3.05
# Script: Latin
# Script confidence: 18.33

# %%
def avg(arr):
    sum=0
    cnt=0
    for i in arr:
        sum+=i
        #sum=sum/len(arr)
    return(sum/len(arr))

# %%
if __name__ == '__main__':
    n=int(input())
    arr =list(map(int,input().split()))
    result= avg(arr)
    print(result)
# Out:
# 1
# 1
# 1.0

# %%
arr =[1,1,1,1,1]

# %%
print(avg(arr))
# Out:
# 1.0
